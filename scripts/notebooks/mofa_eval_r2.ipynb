# %%
from mofapy2.run.entry_point import entry_point
import pandas as pd
import numpy as np
import os
import scanpy as sc
import mofax as mfx

from umap import UMAP
import matplotlib.pyplot as plt
import seaborn as sns
import decoupler as dc
import plotnine as pn

# initialise the entry point
ent = entry_point()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################

# %%
current_path = globals()["_dh"][0]
out_file = current_path / ".." / ".." / "data" / "prc" / "vis" / "mofa_test.hdf5" / "cellranger"
visium_path = current_path / ".." / ".." / "data" / "prc" / "vis" / "processed"
visium_samples = [f.split(".")[0] for f in os.listdir(visium_path) if not f.startswith(".")]
print(np.array(visium_samples))
# Out:
# ['MS549H' 'CO85' 'MS371' 'MS197U' 'cellranger' 'CO41' 'MS377T' 'MS229'
#  'CO37' 'MS497I' 'CO40' 'CO96' 'MS371N' 'cellbender' 'MS586' 'MS197D'
#  'MS94' 'CO74' 'MS377N' 'MS549T' 'MS411' 'MS466' 'MS377I' 'MS497T']

# %%
sample_meta = pd.read_excel(current_path / ".." / ".." / "data" / "Metadata_all.xlsx", sheet_name="Visium")

# %%
df_list = []
for model in ["all", "condition"]:
    for ct_metric in ["abunds", "props_ilr"]:
        for image_features in ["None", "histogram", "summary", "texture"]:
            for n_factors in [5, 10]:
                out_dir = current_path / ".." / ".." / "data" / "prc" / "vis" / "mofa_tests" / "cellranger" / f"{model}__{ct_metric}__{image_features}__{str(n_factors)}"
                out_file = out_dir / "mofa_model.hdf5"
                if out_file.exists():
                    print(f"Processing {out_file}")
                    m = mfx.mofa_model(out_file)
                    df = m.get_r2()
                    df = df[~df.View.isin(["histogram", "summary", "texture"])] # remove all image_feature views: ["histogram", "summary", "texture"]
                    # geometric mean over views, sum over factors, mean over groups
                    stat1 = df.drop("View", axis=1).groupby(["Group", "Factor"]).apply(lambda x: np.prod(x)**(1/len(x))).groupby("Group").sum().R2.mean()
                    stat2 = df.drop("View", axis=1).groupby(["Group", "Factor"]).apply(lambda x: np.prod(x)**(1/len(x))).groupby("Group").sum().R2.median()
                    df_out = pd.DataFrame({"model": model, "ct_metric": ct_metric, "image_features": image_features, "set_factors": n_factors, "stat1": stat1, "stat2": stat2}, 
                                          index=[0])
                    df_out["actual_factors"] = m.get_factors().shape[1]
                    df_list.append(df_out)
                else:
                    print(f"File {out_file} does not exist")
df = pd.concat(df_list)
# Out:
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__abunds__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/all__props_ilr__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__abunds__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellranger/condition__props_ilr__texture__10/mofa_model.hdf5

# %%
df.sort_values("stat1", ascending=False)
# Out:
#        model  ct_metric image_features  set_factors      stat1      stat2  \
# 0        all     abunds           None           10  42.543395  43.089174
# 0  condition     abunds           None           10  40.790241  42.444380
# 0        all  props_ilr           None           10  39.474224  36.387187
# 0        all     abunds        summary           10  38.174827  34.399149
# 0  condition     abunds      histogram           10  37.688627  38.010399
# 0        all  props_ilr        summary           10  37.282680  34.526308
# 0        all  props_ilr      histogram           10  36.944729  35.241304
# 0        all     abunds        summary            5  35.542744  22.547679
# 0        all     abunds      histogram           10  35.094527  39.672689
# 0        all     abunds           None            5  33.848349  35.237786
# 0  condition  props_ilr        summary           10  33.746517  33.254068
# 0  condition     abunds        summary           10  33.150691  25.992575
# 0  condition  props_ilr           None           10  33.065878  32.323829
# 0  condition     abunds           None            5  32.659946  35.719330
# 0        all  props_ilr           None            5  32.468404  30.622704
# 0  condition  props_ilr      histogram           10  30.606516  27.651649
# 0  condition     abunds        summary            5  28.985968  28.449670
# 0        all  props_ilr        summary            5  26.079972  24.083517
# 0        all  props_ilr        texture           10  25.827051  23.149989
# 0  condition  props_ilr           None            5  25.675689  25.323362
# 0        all  props_ilr      histogram            5  25.398433  22.857783
# 0        all  props_ilr        texture            5  25.007524  22.054046
# 0  condition  props_ilr        texture           10  23.323394  20.360991
# 0        all     abunds      histogram            5  21.532654  21.580495
# 0  condition     abunds      histogram            5  20.278371  20.466774
# 0        all     abunds        texture           10  20.213388  20.586341
# 0  condition     abunds        texture           10  19.211632  19.460114
# 0  condition  props_ilr        summary            5  18.882433  18.235952
# 0  condition  props_ilr      histogram            5  18.042894  17.594552
# 0  condition  props_ilr        texture            5  17.225273  18.532105
# 0        all     abunds        texture            5  16.566552  16.748639
# 0  condition     abunds        texture            5  15.588029  16.223320
#
#    actual_factors
# 0               7
# 0               7
# 0               8
# 0               8
# 0               9
# 0               9
# 0               8
# 0               4
# 0               8
# 0               4
# 0               9
# 0               8
# 0               8
# 0               4
# 0               4
# 0               9
# 0               4
# 0               4
# 0               8
# 0               4
# 0               4
# 0               4
# 0               9
# 0               4
# 0               4
# 0               8
# 0               8
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4

# %%
# scatter plot of stat1 vs stat2
g = pn.ggplot(df, pn.aes(x="stat1", y="stat2")) + pn.geom_point() + pn.geom_smooth(method="lm")
print(g)

# %%
current_path = globals()["_dh"][0]
out_file = current_path / ".." / ".." / "data" / "prc" / "vis" / "mofa_test.hdf5" / "cellbender"
visium_path = current_path / ".." / ".." / "data" / "prc" / "vis" / "processed"
visium_samples = [f.split(".")[0] for f in os.listdir(visium_path) if not f.startswith(".")]
print(np.array(visium_samples))
# Out:
# ['MS549H' 'CO85' 'MS371' 'MS197U' 'cellranger' 'CO41' 'MS377T' 'MS229'
#  'CO37' 'MS497I' 'CO40' 'CO96' 'MS371N' 'cellbender' 'MS586' 'MS197D'
#  'MS94' 'CO74' 'MS377N' 'MS549T' 'MS411' 'MS466' 'MS377I' 'MS497T']

# %%
sample_meta = pd.read_excel(current_path / ".." / ".." / "data" / "Metadata_all.xlsx", sheet_name="Visium")

# %%
df_list = []
for model in ["all", "condition"]:
    for ct_metric in ["abunds", "props_ilr"]:
        for image_features in ["None", "histogram", "summary", "texture"]:
            for n_factors in [5, 10]:
                out_dir = current_path / ".." / ".." / "data" / "prc" / "vis" / "mofa_tests" / "cellbender" / f"{model}__{ct_metric}__{image_features}__{str(n_factors)}"
                out_file = out_dir / "mofa_model.hdf5"
                if out_file.exists():
                    print(f"Processing {out_file}")
                    m = mfx.mofa_model(out_file)
                    df = m.get_r2()
                    df = df[~df.View.isin(["histogram", "summary", "texture"])] # remove all image_feature views: ["histogram", "summary", "texture"]
                    # geometric mean over views, sum over factors, mean over groups
                    stat1 = df.drop("View", axis=1).groupby(["Group", "Factor"]).apply(lambda x: np.prod(x)**(1/len(x))).groupby("Group").sum().R2.mean()
                    stat2 = df.drop("View", axis=1).groupby(["Group", "Factor"]).apply(lambda x: np.prod(x)**(1/len(x))).groupby("Group").sum().R2.median()
                    df_out = pd.DataFrame({"model": model, "ct_metric": ct_metric, "image_features": image_features, "set_factors": n_factors, "stat1": stat1, "stat2": stat2}, 
                                          index=[0])
                    df_out["actual_factors"] = m.get_factors().shape[1]
                    df_list.append(df_out)
                else:
                    print(f"File {out_file} does not exist")
df = pd.concat(df_list)
# Out:
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__abunds__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__None__5/mofa_model.hdf5
# File /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__None__10/mofa_model.hdf5 does not exist
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/all__props_ilr__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__texture__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__abunds__texture__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__None__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__None__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__histogram__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__histogram__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__summary__5/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__summary__10/mofa_model.hdf5
# Processing /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__texture__5/mofa_model.hdf5
# File /Users/pschafer/Projects/VisiumMS/scripts/notebooks/../../data/prc/vis/mofa_tests/cellbender/condition__props_ilr__texture__10/mofa_model.hdf5 does not exist

# %%
df.sort_values("stat1", ascending=False)
# Out:
#        model  ct_metric image_features  set_factors      stat1      stat2  \
# 0  condition     abunds           None           10  44.773670  46.698581
# 0        all     abunds           None           10  44.743631  49.801466
# 0        all     abunds      histogram           10  39.360460  44.808427
# 0  condition     abunds      histogram           10  37.658360  41.496984
# 0        all     abunds        summary           10  37.156022  33.744141
# 0        all     abunds           None            5  37.146566  43.331486
# 0  condition     abunds           None            5  37.066543  40.625168
# 0  condition     abunds        summary           10  36.845571  31.174709
# 0        all  props_ilr      histogram           10  34.380994  33.100176
# 0  condition  props_ilr           None           10  34.349229  34.271526
# 0        all     abunds        summary            5  32.391242  34.184538
# 0        all  props_ilr        summary           10  32.265405  32.186452
# 0  condition  props_ilr        summary           10  31.552588  29.405335
# 0  condition     abunds        summary            5  30.330004  33.222536
# 0  condition  props_ilr      histogram           10  29.925310  30.032201
# 0        all  props_ilr           None            5  29.166580  26.990782
# 0  condition  props_ilr           None            5  24.842987  23.636388
# 0        all     abunds      histogram            5  24.385837  26.669952
# 0  condition     abunds      histogram            5  23.536170  24.450841
# 0        all     abunds        texture           10  23.217670  25.458399
# 0        all  props_ilr        summary            5  21.995318  19.416822
# 0  condition     abunds        texture           10  21.611005  23.530602
# 0        all  props_ilr      histogram            5  19.893660  18.652488
# 0  condition  props_ilr        summary            5  19.486319  17.080530
# 0        all     abunds        texture            5  18.898054  20.762574
# 0  condition     abunds        texture            5  18.583862  19.949599
# 0  condition  props_ilr      histogram            5  17.178884  15.536155
# 0        all  props_ilr        texture           10  12.689582  10.708384
# 0        all  props_ilr        texture            5  12.068845  10.286506
# 0  condition  props_ilr        texture            5  10.699871   9.624071
#
#    actual_factors
# 0               7
# 0               7
# 0               9
# 0               9
# 0               8
# 0               4
# 0               4
# 0               8
# 0               9
# 0               9
# 0               4
# 0               9
# 0               9
# 0               4
# 0               9
# 0               4
# 0               4
# 0               4
# 0               4
# 0               9
# 0               4
# 0               8
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               7
# 0               4
# 0               4

# %%
# scatter plot of stat1 vs stat2
g = pn.ggplot(df, pn.aes(x="stat1", y="stat2")) + pn.geom_point() + pn.geom_smooth(method="lm")
print(g)
